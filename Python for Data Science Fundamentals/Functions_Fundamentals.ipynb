# %%
  
print("## 1. Functions ##")

a_list = [4444, 8897, 6340, 9896, 4835, 4324, 10, 6445,
          661, 1246, 1000, 7429, 1376, 8121, 647, 1280,
          3993, 4881, 9500, 6701, 1199, 6251, 4432, 37]
sum_manual = 0
for list_element in a_list:
    sum_manual += list_element

print(sum_manual)
sum(a_list)

print("## 2. Built-in Functions ##")

ratings = ['4+', '4+', '4+', '9+', '12+', '12+', '17+', '17+']
content_ratings = {}

for rating in ratings:
    if rating in content_ratings:
        content_ratings[rating] += 1
    else:
        content_ratings[rating] = 1
        
print(content_ratings)

print("## 3. Creating Our Own Functions ##")

def square(a_number):
    squared_number = a_number * a_number
    return squared_number

squared_10 = square(a_number=10)
print(squared_10)
squared_16 = square(a_number=16)

## 4. The Structure of a Function ##

def add_10(number):
    result = number + 10
    return result

add_30 = add_10(number=30)
add_90 = add_10(number=90)
print(add_90)

print("## 5. Parameters and Arguments ##")

def square(a_number):
    return a_number * a_number

squared_6 = square(6)
squared_11 = square(11)

print(squared_11)

print("## 6. Extract Values From Any Column ##")

opened_file = open('apple-store.csv')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)
def extract(index):
    column = []    
    for row in apps_data[1:]:
        value = row[index]
        column.append(value)    
    return column

genres = extract(12)
print("All type of genres\n")
print(genres)
print("------------------------------------------------")

print("## 7. Creating Frequency Tables ##")

# CODE FROM THE PREVIOUS SCREEN
opened_file = open('apple-store.csv')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

def extract(index):
    column = []    
    for row in apps_data[1:]:
        value = row[index]
        column.append(value)    
    return column

genres = extract(12)
# SOLUTION CODE
def freq_table(column):
    frequency_table = {}    
    for value in column:
        if value in frequency_table:
            frequency_table[value] += 1
        else:
            frequency_table[value] = 1            
    return frequency_table

genres_ft = freq_table(genres)
print("-------------------------------")
print(genres_ft)

print("## 8. Writing a Single Function ##")

opened_file = open('apple-store.csv')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)
def freq_table(index):
    frequency_table = {}
    
    for row in apps_data[1:]:
        value = row[index]
        if value in frequency_table:
            frequency_table[value] += 1
        else:
            frequency_table[value] = 1
            
    return frequency_table

ratings_ft = freq_table(8)
print("user rating\n")
print(ratings_ft)

print("## 9. Reusability and Multiple Parameters ##")

opened_file = open('apple-store.csv')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

# INITIAL FUNCTION
def freq_table(index):
    frequency_table = {}
    
    for row in apps_data[1:]:
        value = row[index]
        if value in frequency_table:
            frequency_table[value] += 1
        else:
            frequency_table[value] = 1
            
    return frequency_table
# UPDATED FUNCTION
def freq_table(data_set, index):
    frequency_table = {}
    
    for row in data_set[1:]:
        value = row[index]
        if value in frequency_table:
            frequency_table[value] += 1
        else:
            frequency_table[value] = 1
    
    return frequency_table

ratings_ft = freq_table(data_set=apps_data, index=8)
print("--------------------------------")
print(ratings_ft)

print("## 10. Keyword and Positional Arguments ##")

opened_file = open('apple-store.csv')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

def freq_table(data_set, index):
    frequency_table = {}
    
    for row in data_set[1:]:
        value = row[index]
        if value in frequency_table:
            frequency_table[value] += 1
        else:
            frequency_table[value] = 1
        
    return frequency_table
print("content rating table having each rating particular total count ")
print("=-=-=-=-=-=-=-=-=-=========================-=-=-=-=-=+++++++++++++++++++++++++")
content_ratings_ft = freq_table(apps_data, 11)
print(content_ratings_ft)
print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
ratings_ft = freq_table(data_set=apps_data, index=8)
print("ratings_ft")
print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
print(ratings_ft)
genres_ft = freq_table(index=12, data_set=apps_data)
print("genres_ft")
print(genres_ft)

print("## 11. Combining Functions ##")

opened_file = open('apple-store.csv')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)
#for extracting data for a particular row
def extract(data_set, index):
    column = []    
    for row in data_set[1:]:
        value = row[index]
        column.append(value)    
    return column
#to get sum of that row
def find_sum(a_list):
    a_sum = 0
    for element in a_list:
        a_sum += float(element)
    return a_sum

def find_length(a_list):
    length = 0
    for element in a_list:
        length += 1
    return length
def mean(data_set, index):
    column = extract(data_set, index)
    return find_sum(column) / find_length(column)
    
avg_price = mean(apps_data, 5)
print("avg_price")
print(avg_price)

print("## 12. Debugging Functions ##")

# def extract(data_set, index):
#     column = []
    
#     for row in data_set[1:]:
#         value = row[index]
#         column.append(value)
    
#     return column

# def find_sum(a_list):
#     a_sum = 0
#     for element in a_list
#         a_sum += element
#     return a_sum

# def find_length(a_list):
#     length = 0
#     for element in a_list:
#         length += 1
#     return length

# def mean(data_set, index):
#     column = extract(data_set, index)
#     return find_sm(column) / find_length(column)

# avg_price = mean(apps_data, 4)
# avg_rating = mean(apps_data, 7)
# SOLUTION CODE
opened_file = open('apple-store.csv')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

def extract(data_set, index):
    column = []
    
    for row in data_set[1:]:
        value = row[index]
        column.append(value)
    
    return column

def find_sum(a_list):
    a_sum = 0
    for element in a_list:
        a_sum += float(element)
    return a_sum

def find_length(a_list):
    length = 0
    for element in a_list:
        length += 1
    return length

def mean(data_set, index):
    column = extract(data_set, index)
    return find_sum(column) / find_length(column)
    
avg_price = mean(apps_data, 5)
print("average Price")
print(avg_price)
print(" =============================================")
avg_rating = mean(apps_data, 8)
print("avearge rating")
print(avg_rating)
# Out:
# ## 1. Functions ##
# 103945
# ## 2. Built-in Functions ##
# {'4+': 3, '9+': 1, '12+': 2, '17+': 2}
# ## 3. Creating Our Own Functions ##
# 100
# 100
# ## 5. Parameters and Arguments ##
# 121
# ## 6. Extract Values From Any Column ##
# All type of genres
#
# ...
