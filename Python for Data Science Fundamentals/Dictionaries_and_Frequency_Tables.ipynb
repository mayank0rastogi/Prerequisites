# %%
print("## 1. Storing Data ##\n")

print("# Creating Two lists")
content_ratings = ['4+', '9+', '12+', '17+']
numbers = [4433, 987, 1155, 622]

# A list of lists
content_rating_numbers = [['4+', '9+', '12+', '17+'],
                          [4433, 987, 1155, 622]]

print("## 2. Dictionaries ##")
print("===============================================================\n")

content_ratings = {'4+': 4433, '9+': 987, '12+': 1155, '17+': 622}

print(content_ratings)
print("===============================================================\n")

print("## 3. Indexing ##\n")

content_ratings = {'4+': 4433, '9+': 987, '12+': 1155, '17+': 622}
over_9 = content_ratings['9+']
print(over_9,'\n')
print("===============================================================\n")
over_17 = content_ratings['17+']
print(over_17,"\n")
print("===============================================================\n\n\n")


print("## 4. Alternative Way of Creating a Dictionary ##\n")

content_ratings = {} 
content_ratings['4+'] = 4433
content_ratings['9+'] = 987
content_ratings['12+'] = 1155
content_ratings['17+'] = 622

over_12_n_apps = content_ratings['12+']
print(over_12_n_apps,"\n")
print("===============================================================\n")

print("## 5. Key-Value Pairs ##")

d_1 = {'key_1': 'first_value', 
       'key_2': 2,
       'key_3': 3.14,
       'key_4': True,
       'key_5': [4,2,1],
       'key_6': {'inner_key' : 6}}

error = True
print(d_1)
print("===============================================================\n")

print("## 6. Checking for Membership ##\n")

content_ratings = {'4+': 4433, '9+': 987, '12+': 1155, '17+': 622}

is_in_dictionary_1 = '9+' in content_ratings
print(is_in_dictionary_1)
print("===============================================================\n")
is_in_dictionary_2 = 987 in content_ratings
print(is_in_dictionary_2)
print("===============================================================\n")

if '17+' in content_ratings:
    result = "It exists"
    print(result)
    print("===============================================================\n")

print("# Alternative solution\n")
is_in_dictionary = '17+' in content_ratings
if is_in_dictionary:
    result = "It exists"
    print(result)
    print("===============================================================")

print("## 7. Counting with Dictionaries ##")

opened_file = open('apple-store.csv')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)
content_ratings = {'4+': 0, '9+': 0, '12+': 0, '17+': 0}
print(content_ratings)
print("===============================================================\n")

for row in apps_data[1:]:
    c_rating = row[10]
    if c_rating in content_ratings:
        content_ratings[c_rating] += 1
        
print(content_ratings)
print("===============================================================\n")
print("## 8. Finding the Unique Values ##\n")
print("===============================================================")

opened_file = open('apple-store.csv')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)
content_ratings = {}

for row in apps_data[1:]:
    c_rating = row[11]
    if c_rating in content_ratings:
        content_ratings[c_rating] += 1
    else:
        content_ratings[c_rating] = 1
        
print(content_ratings)
print("===============================================================")

print("## 9. Proportions and Percentages ##")
print("===============================================================")

opened_file = open('apple-store.csv')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)
genre_counting = {}

for row in apps_data[1:]:
    genre = row[12]    
    if genre in genre_counting:
        genre_counting[genre] += 1
    else:
        genre_counting[genre] = 1
        
print(genre_counting)
print("===============================================================")

# The most common app genre is 'Games' (there are 3862 gaming apps)

print("## 10. Looping over Dictionaries ##")

content_ratings = {'4+': 4433, '12+': 1155, '9+': 987, '17+': 622}
total_number_of_apps = 7197
for rating in content_ratings:
    content_ratings[rating] /= total_number_of_apps
    content_ratings[rating] *= 100
print(content_ratings)
print("===============================================================")
    
percentage_17_plus = content_ratings['17+']
print(percentage_17_plus)
print("===============================================================")
percentage_15_allowed = content_ratings['4+'] + content_ratings['9+'] + content_ratings['12+']
print(percentage_15_allowed)
print("===============================================================")
print("## 11. Keeping the Dictionaries Separate ##")
print("===============================================================")

content_ratings = {'4+': 4433, '12+': 1155, '9+': 987, '17+': 622}
total_number_of_apps = 7197
c_ratings_proportions = {}
for key in content_ratings:
    proportion = content_ratings[key] / total_number_of_apps    
    c_ratings_proportions[key] = proportion
print(c_ratings_proportions)
print("===============================================================")
c_ratings_percentages = {}
for key in c_ratings_proportions:
    percentage = c_ratings_proportions[key] * 100
    c_ratings_percentages[key] = percentage


print(c_ratings_percentages)
print("===============================================================")

print("## 12. Frequency Tables for Numerical Columns ##\n")

opened_file = open('apple-store.csv')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)
data_sizes = []
for row in apps_data[1:]:
    size = float(row[3])
    data_sizes.append(size)

print(data_sizes)
print("===============================================================\n")   
min_size = min(data_sizes)
print(min_size)
print("===============================================================\n")
max_size = max(data_sizes)
print(max_size)
print("===============================================================\n")
# Out:
# ## 1. Storing Data ##
#
# # Creating Two lists
# ## 2. Dictionaries ##
# ...
#
# {'4+': 4433, '9+': 987, '12+': 1155, '17+': 622}
# ...
#
# ## 3. Indexing ##
#
# 987
#
# ...
#
# 622
#
# ...
#
#
#
# ## 4. Alternative Way of Creating a Dictionary ##
#
# 1155
#
# ...
#
# ## 5. Key-Value Pairs ##
# {'key_1': 'first_value', 'key_2': 2, 'key_3': 3.14, 'key_4': True, 'key_5': [4, 2, 1], 'key_6': {'inner_key': 6}}
# ...
#
# ## 6. Checking for Membership ##
#
# True
# ...
#
# False
# ...
#
# It exists
# ...
#
# # Alternative solution
#
# It exists
# ...
# ## 7. Counting with Dictionaries ##
# {'4+': 0, '9+': 0, '12+': 0, '17+': 0}
# ...
#
# {'4+': 0, '9+': 0, '12+': 0, '17+': 0}
# ...
#
# ## 8. Finding the Unique Values ##
#
# ...
# {'4+': 4433, '12+': 1155, '17+': 622, '9+': 987}
# ...
# ## 9. Proportions and Percentages ##
# ...
